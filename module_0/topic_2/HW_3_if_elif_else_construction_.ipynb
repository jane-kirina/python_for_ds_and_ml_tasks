# %% [markdown]
# <a href="https://colab.research.google.com/github/jane-kirina/python_for_ds_and_ml_tasks/blob/main/module_0/topic_2/HW_3_if_elif_else_construction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Основи роботи з умовними конструкціями (if-elif-else)**
#
# Створіть змінну `cooking_time = 5` (час варіння яєць у хвилинах)
#
# Напишіть програму, яка виводить (кожен пункт оцінюється в 0.5 бала):
# - "Яйце рідке" якщо cooking_time < 4
# - "Яйце всмятку" якщо 4 <= cooking_time < 7
# - "Яйце вкруту" якщо 7 <= cooking_time < 10
# - "Яйце переварене" якщо cooking_time >= 10

# %%
cooking_time = 5

if cooking_time < 4:
  print('Яйце рідке')
elif cooking_time <= 4 and cooking_time < 7:
  print('Яйце всмятку')
elif cooking_time <= 7 and cooking_time < 10:
  print('Яйце вкруту')
elif cooking_time >= 10:
  print('Яйце переварене')
else:
  print('З яйцем щось не те...')
# Out:
# Яйце вкруту

# %% [markdown]
# ---
#
# **2. Перевірка оцінки**
#
# Створіть змінну `grade = 72`
#
# Напишіть програму, яка виводить (кожен пункт оцінюється в 0.5 бала):
# - "Відмінно" якщо grade >= 90
# - "Добре" якщо 75 <= grade < 90
# - "Задовільно" якщо 60 <= grade < 75
# - "Незадовільно" якщо grade < 60

# %%
grade = 72

if grade >= 90:
    print("Відмінно")
elif 75 <= grade < 90:
    print("Добре")
elif 60 <= grade < 75:
    print("Задовільно")
else:
    print("Незадовільно")
# Out:
# Задовільно

# %% [markdown]
# ---
#
# **3. Перевірка на наявність**
#
# Створіть список продуктів в холодильнику зі значеннями ["молоко", "яйця", "масло", "сир"] і запишіть його в змінну.
#
#
# Напишіть код, який перевіряє (кожен пункт оцінюється в 0.5 бала):
# - Чи є "яйця" в списку (виведіть "Яйця є в холодильнику" або "Яєць немає")
# - Чи є "хліб" в списку

# %%
# З використанням тернарної операції
food =  ["молоко", "яйця", "масло", "сир"]

result_egg = "Яйця є в холодильнику" if "яйця" in food else "Яєць немає"
print(result_egg)

result_bread = "Хліб є в холодильнику" if "хліб" in food else "Хліба немає"
print(result_bread)
# Out:
# Яйця є в холодильнику
# Хліба немає
